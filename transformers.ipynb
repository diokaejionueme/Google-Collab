# %% [markdown]
# <a href="https://colab.research.google.com/github/diokaejionueme/Google-Collab/blob/learning/transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
classifier(["I enjoyed my vacation this weekend", "I have hated every day here in Abuja", "I enjoy going on walks", "I am going to teach Jessica driving t"])
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9998595714569092},
#  {'label': 'NEGATIVE', 'score': 0.9944196343421936},
#  {'label': 'POSITIVE', 'score': 0.9994839429855347},
#  {'label': 'NEGATIVE', 'score': 0.9763137698173523}]
