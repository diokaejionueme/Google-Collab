# %% [markdown]
# <a href="https://colab.research.google.com/github/diokaejionueme/Google-Collab/blob/learning/transformers3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install sacremoses
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 11.2 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

translator = pipeline("translation", model="Helsinki-NLP/opus-mt-en-es")
translator("My name is Dioka Ejionueme")
# Out:
# Device set to use cpu
# [{'translation_text': 'Mi nombre es Dioka Ejionueme.'}]
